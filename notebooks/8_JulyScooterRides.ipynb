# %%
from shapely.geometry import Point
import pandas as pd
import pickle
import matplotlib.pyplot as plt
from datetime import date, timedelta, datetime
import geopandas as gpd

# %% [markdown]
# loading may data - pickle and csv

# %%
# %%time
july_loc = pd.read_pickle("../data/july.pkl")
july_trip = pd.read_csv("../data/july_trip.csv")
# Out:
# Wall time: 5.01 s

# %%
july_trip['pubTimeStamp'] = pd.to_datetime(july_trip['pubTimeStamp'])

# %% [markdown]
# This section makes a dictionary of dataframes. The dataframes can be "chunked up" into different time segments. The main things you need to adjust: the start and end variables, and the delta variable, which designates how "big" a "time chunk" should be.

# %%
#make a list of datetimes with datetime function 
start = datetime(2019, 7, 6, 0, 0)
end = datetime(2019, 7, 7, 0, 0)
delta = timedelta(days=1)
timelist = []
timenamelist = []
while start <= end:
    timelist.append(start)
    timenamelist.append(start.strftime("%Y-%m-%d-%H-%M"))
    start += delta
# print(timelist)
# print(timenamelist)

# %%
#goal of function: using list of time frames, in this case, days, make a dataframe containing
#info about the location for each scooter, for each day


#make dictionary of dataframes using base dataframe and a user-defined segments_of_time_list
#from cell above
def make_day_df(datetime_list, timenames_list, dataframe, colname):
    resultslist = {} #turn into dictionary
    x = 0
    y = 1
    z = 0
    while x in range(0,len(datetime_list)-1):
        starttime = datetime_list[x]
        endtime = datetime_list[y]
        mask = (dataframe[colname] > starttime) & (dataframe[colname] <= endtime)
        framename = dataframe.loc[mask]
        x += 1
        y += 1
        print(x)
        resultslist[timenames_list[z]] = framename
        z += 1
    return resultslist
        
the_output = make_day_df(timelist, timenamelist, july_trip,"pubTimeStamp")
# Out:
# 1

# %%
the_output.keys()
# Out:
# dict_keys(['2019-07-06-00-00'])

# %% [markdown]
# I'm interested in May 26th specifically, the Saturday of Memorial Day weekend, since it had the most scooter rides.

# %%
the_output['2019-07-06-00-00']
# the_output['2019-05-01-00-00']['sumdid'].nunique()
# Out:
#                  pubTimeStamp companyName tripRecordNum         sumdID  \
# 23989 2019-07-06 00:00:08.400        Lyft          LFT1  Powered120606
# 23990 2019-07-06 00:00:16.080        Lyft          LFT2  Powered852889
# 23991 2019-07-06 00:00:37.000      Gotcha          GOT1    Powered2367
# 23992 2019-07-06 00:00:38.007        Lyft          LFT3  Powered131810
# 23993 2019-07-06 00:00:49.097        Lyft          LFT4  Powered122977
# ...                       ...         ...           ...            ...
# 32060 2019-07-06 23:59:26.363        Bird       BRD7616   PoweredYVI65
# 32061 2019-07-06 23:59:26.363        Bird       BRD7618   PoweredXH9DD
# 32062 2019-07-06 23:59:26.363        Bird       BRD7614   PoweredU7KRD
# 32063 2019-07-06 23:59:26.363        Bird       BRD7615   Powered2MQXF
# 32064 2019-07-06 23:59:26.363        Bird       BRD7617   Powered3JRM3
#
#        tripDuration  tripDistance            startDate        startTime  \
# 23989     21.625550   9025.590840  2019-07-05 00:00:00  23:38:30.720000
# 23990      9.482850   6335.302040  2019-07-05 00:00:00  23:50:47.010000
# 23991      3.000000    514.675213  2019-07-06 00:00:00         00:00:40
# 23992     10.481733   6335.302040  2019-07-05 00:00:00  23:50:08.920000
# 23993      9.127350    738.189000  2019-07-05 00:00:00  23:51:41.363333
# the_output['2019-05-01-00-00']['sumdid'].nunique()
# Out:
# PoweredUNKNOWN          26
# PoweredYTND2AVKAXKSI    15
# PoweredFK44MOS4X2Y76    14
# PoweredHEKRYNEB4AMZY    13
# Powered892995           13
#                         ..
# PoweredMIXNW             1
# PoweredFWI2W             1
# PoweredP2DQ2             1
# PoweredFYJPZ             1
# Powered3JRM3             1
# Name: sumdID, Length: 2656, dtype: int64

# %% [markdown]
# 2630 unique scooters this day (subtracted unknowns)

# %%
the_output['2019-07-06-00-00']['sumdID'].value_counts().loc[lambda x : x<3]
# Out:
# PoweredWRTN1     2
# PoweredL51XC     2
# Powered502227    2
# Powered953918    2
# Powered742       2
#                 ..
# PoweredMIXNW     1
# PoweredFWI2W     1
# PoweredP2DQ2     1
# PoweredFYJPZ     1
# Powered3JRM3     1
# Name: sumdID, Length: 1341, dtype: int64

# %% [markdown]
# 1341 had fewer than 3 rides. 1315 had 3 or more, or 50%.

# %%
the_output['2019-07-06-00-00']['sumdID'].value_counts().loc[lambda x : x>5]
# Out:
# PoweredUNKNOWN          26
# PoweredYTND2AVKAXKSI    15
# PoweredFK44MOS4X2Y76    14
# PoweredHEKRYNEB4AMZY    13
# Powered892995           13
#                         ..
# Powered991401            6
# Powered874268            6
# PoweredMJYTSRKL7J3UW     6
# Powered869301            6
# Powered552055            6
# Name: sumdID, Length: 329, dtype: int64

# %% [markdown]
# 303 had 6 or more rides. 12%

# %%
#make a list of datetimes with datetime function 
start = datetime(2019, 7, 25, 0, 0)
end = datetime(2019, 7, 26, 0, 0)
delta = timedelta(days=1)
timelist = []
timenamelist = []
while start <= end:
    timelist.append(start)
    timenamelist.append(start.strftime("%Y-%m-%d-%H-%M"))
    start += delta
# print(timelist)
# print(timenamelist)

# %%
#goal of function: using list of time frames, in this case, days, make a dataframe containing
#info about the location for each scooter, for each day


#make dictionary of dataframes using base dataframe and a user-defined segments_of_time_list
#from cell above
def make_day_df(datetime_list, timenames_list, dataframe, colname):
    resultslist = {} #turn into dictionary
    x = 0
    y = 1
    z = 0
    while x in range(0,len(datetime_list)-1):
        starttime = datetime_list[x]
        endtime = datetime_list[y]
        mask = (dataframe[colname] > starttime) & (dataframe[colname] <= endtime)
        framename = dataframe.loc[mask]
        x += 1
        y += 1
        print(x)
        resultslist[timenames_list[z]] = framename
        z += 1
    return resultslist
        
the_output = make_day_df(timelist, timenamelist, july_trip,"pubTimeStamp")
# Out:
# 1

# %%
the_output.keys()
# Out:
# dict_keys(['2019-07-25-00-00'])

# %%
the_output['2019-07-25-00-00']
# the_output['2019-05-01-00-00']['sumdid'].nunique()
# Out:
#                   pubTimeStamp companyName tripRecordNum         sumdID  \
# 103750 2019-07-25 00:01:05.680        Lyft          LFT1  Powered583424
# 103751 2019-07-25 00:02:19.287        Lyft          LFT2  Powered459446
# 103752 2019-07-25 00:02:41.847        Lyft          LFT3  Powered493989
# 103753 2019-07-25 00:02:49.590        Lyft          LFT4  Powered982090
# 103754 2019-07-25 00:02:55.850        Lyft          LFT5  Powered089301
# ...                        ...         ...           ...            ...
# 107141 2019-07-25 23:59:56.603        Bird       BRD1886   PoweredU8GCD
# 107142 2019-07-25 23:59:56.603        Bird       BRD1885   Powered6SN6J
# 107143 2019-07-25 23:59:56.603        Bird       BRD1887   PoweredHSFX2
# 103753  2019-07-26 11:00:21.653000
# 103754  2019-07-26 11:00:21.687000
# ...                            ...
# 107141  2019-07-27 05:30:22.097000
# 107142  2019-07-27 05:30:22.060000
# 107143  2019-07-27 05:30:22.130000
# 107144  2019-07-27 05:30:22.160000
# 107145  2019-07-27 05:30:22.027000
#
# [3396 rows x 16 columns]

# %%
the_output['2019-07-25-00-00']['sumdID'].value_counts()
# the_output['2019-05-01-00-00']['sumdid'].nunique()
# Out:
# Powered013009           11
# PoweredEDBDXLOZJAP6Z    10
# PoweredFR3FK5ZFAH6GV    10
# PoweredJ4W5YLZEMBDX2     9
# Powered2QRBDKCVO7WMG     9
#                         ..
# Powered9VGFW             1
# Powered2UVN8             1
# PoweredUG5TH             1
# PoweredUF71S             1
# PoweredYUL2B             1
# Name: sumdID, Length: 1435, dtype: int64

# %%
the_output['2019-07-25-00-00']['sumdID'].value_counts().loc[lambda x : x<3]
# Out:
# PoweredDLTTJ                                    2
# Powered-05fedb39-a00f-a5e0-2219-8c3c7dd1b80e    2
# Powered-d0ce22ca-e941-4fd6-55f2-d4eb9d187d22    2
# PoweredUWKW3                                    2
# Powered3987919                                  2
#                                                ..
# Powered9VGFW                                    1
# Powered2UVN8                                    1
# PoweredUG5TH                                    1
# PoweredUF71S                                    1
# PoweredYUL2B                                    1
# Name: sumdID, Length: 939, dtype: int64

# %% [markdown]
# 35% had 3 or more

# %%
the_output['2019-07-25-00-00']['sumdID'].value_counts().loc[lambda x : x>5]
# Out:
# Powered013009           11
# PoweredEDBDXLOZJAP6Z    10
# PoweredFR3FK5ZFAH6GV    10
# PoweredJ4W5YLZEMBDX2     9
# Powered2QRBDKCVO7WMG     9
#                         ..
# PoweredJTXV42MMK5N2K     6
# PoweredOLVUVOGILUDP5     6
# Powered3YI3UZR3YQTLX     6
# PoweredT7ZTXTMBFPADA     6
# PoweredC373KUYMR64SA     6
# Name: sumdID, Length: 80, dtype: int64

# %% [markdown]
# 6% performed well with at least 6 rides that day.

# %%
#make a list of datetimes with datetime function 
start = datetime(2019, 7, 10, 0, 0)
end = datetime(2019, 7, 11, 0, 0)
delta = timedelta(days=1)
timelist = []
timenamelist = []
while start <= end:
    timelist.append(start)
    timenamelist.append(start.strftime("%Y-%m-%d-%H-%M"))
    start += delta
# print(timelist)
# print(timenamelist)

# %%
#goal of function: using list of time frames, in this case, days, make a dataframe containing
#info about the location for each scooter, for each day


#make dictionary of dataframes using base dataframe and a user-defined segments_of_time_list
#from cell above
def make_day_df(datetime_list, timenames_list, dataframe, colname):
    resultslist = {} #turn into dictionary
    x = 0
    y = 1
    z = 0
    while x in range(0,len(datetime_list)-1):
        starttime = datetime_list[x]
        endtime = datetime_list[y]
        mask = (dataframe[colname] > starttime) & (dataframe[colname] <= endtime)
        framename = dataframe.loc[mask]
        x += 1
        y += 1
        print(x)
        resultslist[timenames_list[z]] = framename
        z += 1
    return resultslist
        
the_output = make_day_df(timelist, timenamelist, july_trip,"pubTimeStamp")
# Out:
# 1

# %%
the_output.keys()
# Out:
# dict_keys(['2019-07-10-00-00'])

# %%
the_output['2019-07-10-00-00']
# the_output['2019-05-01-00-00']['sumdid'].nunique()
# Out:
#                  pubTimeStamp companyName tripRecordNum          sumdID  \
# 42305 2019-07-10 00:00:40.880        Lyft          LFT1   Powered658324
# 42306 2019-07-10 00:01:08.693        Lyft          LFT2   Powered258676
# 42307 2019-07-10 00:01:11.083        Lyft          LFT3   Powered302645
# 42308 2019-07-10 00:01:26.883        SPIN        SPI184  Powered7979460
# 42309 2019-07-10 00:01:26.883        SPIN        SPI183  Powered1590780
# ...                       ...         ...           ...             ...
# 44652 2019-07-10 23:58:48.093        Bird       BRD1450    PoweredRVNYX
# 44653 2019-07-10 23:58:48.093        Bird       BRD1448    PoweredWE6DN
# 44654 2019-07-10 23:58:48.093        Bird       BRD1452    Powered64W2E
# 44655 2019-07-10 23:58:48.093        Bird       BRD1454    Powered3ET2X
# 44656 2019-07-10 23:59:53.000      Gotcha         GOT19      Powered375
#
#        tripDuration  tripDistance            startDate        startTime  \
# 42305      6.910900   4012.467320  2019-07-09 00:00:00  23:53:46.110000
# 42306      4.670317   4750.656320  2019-07-09 00:00:00  23:56:28.353333
# 42307      1.666817   1000.656200  2019-07-09 00:00:00  23:59:30.893333
# 42308      8.000000   2273.622120  2019-07-09 00:00:00         23:51:12
# 42309     10.000000   2175.196920  2019-07-09 00:00:00         23:49:48
# ...             ...           ...                  ...              ...
# 44652     10.000000   6889.764000  2019-07-10 00:00:00  23:49:03.830000
# 44653      4.000000   1312.336000  2019-07-10 00:00:00  23:55:52.370000
# 44654     15.000000      0.000000  2019-07-10 00:00:00  23:45:24.333333
# 44655     15.000000   6889.764000  2019-07-10 00:00:00  23:45:01.166666
# 44656     12.000000   1121.922608  2019-07-10 00:00:00         23:59:57
#
#                    endDate          endTime  startLatitude  startLongitude  \
# 42305  2019-07-10 00:00:00  00:00:40.766666      36.156650      -86.783660
# 42306  2019-07-10 00:00:00  00:01:08.573333      36.143130      -86.805480
# 42307  2019-07-10 00:00:00  00:01:10.900000      36.164750      -86.779640
# 42308  2019-07-09 00:00:00         23:59:05      36.153659      -86.783981
# 42309  2019-07-09 00:00:00         23:58:57      36.153725      -86.784130
# ...                    ...              ...            ...             ...
# 44652  2019-07-10 00:00:00  23:59:23.860000      36.140800      -86.794800
# 44653  2019-07-10 00:00:00  23:59:34.530000      36.152500      -86.792100
# 44654  2019-07-11 00:00:00  00:00:06.026666      36.162400      -86.779600
# 44655  2019-07-11 00:00:00  00:00:31.153333      36.165700      -86.780200
# 44656  2019-07-11 00:00:00         00:11:57      36.149962      -86.814472
#
#        endLatitude  endLongitude  \
# 42305    36.162910    -86.776830
# 42306    36.147010    -86.793920
# 42307    36.167110    -86.781280
# 42308    36.158838    -86.788279
# 42309    36.158392    -86.788718
# ...            ...           ...
# 44652    36.151100    -86.784600
# 44653    36.153900    -86.787600
# 44654    36.151400    -86.796000
# 44655    36.152000    -86.779300
# 44656    36.150186    -86.810750
#
#                                                tripRoute  \
# 42305  [[36.15665,-86.78366],[36.15667,-86.78374],[36...
# 42306  [[36.14313,-86.80548],[36.14316,-86.8054],[36....
# 42307  [[36.16475,-86.77964],[36.16489,-86.77973],[36...
# 42308  [[36.1588382,-86.7882792],[36.15835,-86.78905]...
# 42309  [[36.158392277738614,-86.788717876715452],[36....
# ...                                                  ...
# 44652  [[36.140869,-86.794716],[36.140884,-86.794702]...
# 44653  [[36.152524,-86.792008],[36.152471,-86.791896]...
# 44654  [[36.162699,-86.779694],[36.162572,-86.779328]...
# 44655  [[36.165712,-86.780108],[36.165399,-86.780206]...
# 44656  [["36.14996","-86.81447"],["36.14996","-86.814...
#
#                         create_dt
# 42305  2019-07-11 10:45:18.270000
# 42306  2019-07-11 10:45:18.300000
# 42307  2019-07-11 10:45:18.333000
# 42308  2019-07-11 11:37:08.117000
# 42309  2019-07-11 11:37:08.077000
# ...                           ...
# 44652  2019-07-12 05:30:57.567000
# 44653  2019-07-12 05:30:57.500000
# 44654  2019-07-12 05:30:57.630000
# 44655  2019-07-12 05:30:57.697000
# 44656  2019-07-12 07:14:25.947000
#
# [2352 rows x 16 columns]

# %%
the_output['2019-07-10-00-00']['sumdID'].value_counts()
# the_output['2019-05-01-00-00']['sumdid'].nunique()
# Out:
# PoweredSDNMKADCNDCLN    11
# Powered859498            9
# PoweredLOEKT4TNO234U     9
# PoweredCA5X75CSAD7HX     9
# Powered7034091           9
#                         ..
# Powered799T4             1
# Powered2AQ14             1
# Powered021910            1
# Powered8ZWYE             1
# Powered375               1
# Name: sumdID, Length: 1267, dtype: int64

# %% [markdown]
# 1267 scooters total

# %%
the_output['2019-07-10-00-00']['sumdID'].value_counts().loc[lambda x : x<3]
# Out:
# Powered042825     2
# Powered643348     2
# Powered689035     2
# Powered230380     2
# Powered5955447    2
#                  ..
# Powered799T4      1
# Powered2AQ14      1
# Powered021910     1
# Powered8ZWYE      1
# Powered375        1
# Name: sumdID, Length: 998, dtype: int64

# %% [markdown]
# 269 had 3 or more. That's 21%

# %%
the_output['2019-07-10-00-00']['sumdID'].value_counts().loc[lambda x : x>5]
# Out:
# PoweredSDNMKADCNDCLN                            11
# Powered859498                                    9
# PoweredLOEKT4TNO234U                             9
# PoweredCA5X75CSAD7HX                             9
# Powered7034091                                   9
# PoweredUHDEIYYDKBLZB                             8
# Powered070905                                    8
# PoweredB266JN56GCRG5                             8
# PoweredVSEHXDME3WR37                             8
# Powered940487                                    8
# PoweredUADBT5UFY3FHV                             7
# Powered3HJPPUNVYGL45                             7
# Powered6802307                                   7
# PoweredLCGAGM7XUUZCI                             7
# PoweredZ72S7KBKVZWU7                             7
# PoweredC6PDDC6OOF65G                             6
# Powered302645                                    6
# PoweredTVB3YTZZ53TBE                             6
# Powered-fab97df0-bf80-4f5a-6f27-84bfb0e12033     6
# Powered5BMTTDARQ2M6P                             6
# PoweredI5NSEK2GT26BB                             6
# PoweredRITYZFWANFYXJ                             6
# PoweredXHJJUHIQH5ORA                             6
# PoweredMBKVCJG3LUA4O                             6
# Powered384                                       6
# PoweredD2OTOYNGZJL3H                             6
# Name: sumdID, dtype: int64

# %% [markdown]
# 26 scooters had 6 or more rides, or 2%
